# %%
from dotenv import load_dotenv
from src.api.coingecko_client import CoinGeckoClient
from src.database.postgres_manager import DatabaseManager
from src.ml.btc_predictor import BTCPredictor
from src.pipeline.btc_pipeline import BTCDataPipeline
from src.config.settings import get_postgres_settings, get_coingecko_settings

# %%
load_dotenv()
# Out:
# True

# %%
pg_settings = get_postgres_settings()
cg_settings = get_coingecko_settings()

# %%
api_client = CoinGeckoClient(API_KEY=cg_settings.API_KEY, timeout=10)

# %%
db_manager = DatabaseManager(settings=pg_settings)

# %%
predictor = BTCPredictor()

# %%
pipeline = BTCDataPipeline(api_client, db_manager, predictor)

# %%
df_api = pipeline.fetch_data("2025-01-01", "2025-12-31")
print(f"Datos desde la API: {len(df_api)}")
df_api.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df_api = pipeline.fetch_data("2025-01-01", "2025-12-31")
#       2 print(f"Datos desde la API: {len(df_api)}")
#       3 df_api.head()
#
# File ~/projects/predict_BTC/src/pipeline/btc_pipeline.py:24, in BTCDataPipeline.fetch_data(self, start_date, end_date)
#      22 """Fetch BTC prices from CoinGecko API."""
#      23 logger.info(f"Fetching data from {start_date} to {end_date} from CoinGecko...")
# ---> 24 df = self.api_client.fetch_bitcoin_prices(start_date, end_date)
#      25 return df
#
# File ~/projects/predict_BTC/src/api/coingecko_client.py:74, in CoinGeckoClient.fetch_bitcoin_prices(self, start_date, end_date)
#      66 time.sleep(1)
#      68 response = self.session.get(
#      69     request_config["url"],
#      70     params=request_config["params"],
#      71     timeout=self.timeout
# ...

# %%
import pandas as pd

# %%
df= pd.read_csv('BTCUSD_1d_Binance.csv')

# %%
df.head()
# Out:
#              Open time  ... Ignore
# 0  2017-08-17 04:00:00  ...    0.0
# 1  2017-08-18 00:00:00  ...    0.0
# 2  2017-08-19 00:00:00  ...    0.0
# 3  2017-08-20 00:00:00  ...    0.0
# 4  2017-08-21 00:00:00  ...    0.0
#
# [5 rows x 12 columns]

# %%
print(df.columns.tolist())
# Out:
# ['Open time', 'Close time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Quote asset volume', 'Number of trades', 'Taker buy base asset volume', 'Taker buy quote asset volume', 'Ignore']

# %%
print(df.dtypes)
# Out:
# Open time                        object
# Close time                       object
# Open                            float64
# High                            float64
# Low                             float64
# Close                           float64
# Volume                          float64
# Quote asset volume              float64
# Number of trades                float64
# Taker buy base asset volume     float64
# Taker buy quote asset volume    float64
# Ignore                          float64
# dtype: object

# %%
print(df['Close'].head(10))
# Out:
# 0    4285.08
# 1    4108.37
# 2    4139.98
# 3    4086.29
# 4    4016.00
# 5    4040.00
# 6    4114.01
# 7    4316.01
# 8    4280.68
# 9    4337.44
# Name: Close, dtype: float64

# %%
# Convert column
df['Open time']=pd.to_datetime(df['Open time'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Convert column
# ----> 2 df['Open time']=pd.to_datetime(df['Open time'])
#
# NameError: name 'pd' is not defined

# %%
start_date = '2025-01-01'
end_date = '2025-09-30'

# Create mask using the column date
mask = (df['Open time'] >= start_date) & (df['Open time'] <= end_date)
df_filtered = df.loc[mask]

print(f"Registros del rango: {len(df_filtered)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 end_date = '2025-09-30'
#       4 # Create mask using the column date
# ----> 5 mask = (df['Open time'] >= start_date) & (df['Open time'] <= end_date)
#       6 df_filtered = df.loc[mask]
#       8 print(f"Registros del rango: {len(df_filtered)}")
#
# NameError: name 'df' is not defined

# %%
precios_cierre = df_filtered['Close'].values
print(precios_cierre[:10])
# Out:
# [ 94591.79  96984.79  98174.18  98220.5   98363.61 102235.6   96954.61
#   95060.61  92552.49  94726.11]

# %%
from src.database.postgres_manager import DatabaseManager
from src.config.settings import get_postgres_settings

# %%
pg_settings = get_postgres_settings()

db_manager = DatabaseManager(settings=pg_settings)

# %%
df = db_manager.get_btc_prices("2025-10-01", "2025-12-31")
# Out:
# Error connecting to PostgreSQL: (psycopg2.OperationalError) connection to server at "localhost" (127.0.0.1), port 5433 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Database read permission error: (psycopg2.OperationalError) connection to server at "localhost" (127.0.0.1), port 5433 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/projects/predict_BTC/env/lib/python3.10/site-packages/sqlalchemy/engine/base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
# ...

# %%
df["date"].value_counts().to_dict()
# Out:
# {datetime.date(2025, 12, 1): 1309,
#  datetime.date(2025, 12, 2): 1309,
#  datetime.date(2025, 12, 3): 1309,
#  datetime.date(2025, 12, 4): 1309,
#  datetime.date(2025, 12, 6): 1285,
#  datetime.date(2025, 12, 5): 1285,
#  datetime.date(2025, 12, 7): 1285,
#  datetime.date(2025, 12, 8): 1285,
#  datetime.date(2025, 12, 11): 1285,
#  datetime.date(2025, 12, 10): 1285,
#  datetime.date(2025, 12, 9): 1285,
#  datetime.date(2025, 12, 12): 1261,
#  datetime.date(2025, 12, 14): 1261,
#  datetime.date(2025, 12, 13): 1261,
#  datetime.date(2025, 12, 15): 973,
#  datetime.date(2025, 12, 16): 973,
#  datetime.date(2025, 12, 19): 973,
#  datetime.date(2025, 12, 18): 973,
#  datetime.date(2025, 12, 17): 973,
#  datetime.date(2025, 11, 9): 781,
#  datetime.date(2025, 11, 2): 781,
#  datetime.date(2025, 11, 3): 781,
#  datetime.date(2025, 11, 4): 781,
#  datetime.date(2025, 11, 5): 781,
#  datetime.date(2025, 11, 1): 781,
#  datetime.date(2025, 11, 12): 781,
#  datetime.date(2025, 11, 11): 781,
# ...

# %%
df
# Out:
#              date      price_usd
# 0      2025-10-01  117481.287601
# 1      2025-10-01  117273.633764
# 2      2025-10-01  116868.506493
# 3      2025-10-01  117704.379056
# 4      2025-10-01  117484.314214
# ...           ...            ...
# 66399  2025-12-31   87611.878669
# 66400  2025-12-31   87409.559581
# 66401  2025-12-31   88414.628561
# 66402  2025-12-31   88414.628561
# 66403  2025-12-31   88414.628561
#
# [66404 rows x 2 columns]

# %%
from src.pipeline.btc_pipeline import BTCDataPipeline

# %%
pipeline =

# %%
df_train = pipeline.get_data_for_training(train_start, train_end)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_train = pipeline.get_data_for_training(train_start, train_end)
#
# NameError: name 'pipeline' is not defined

# %%
fetc
